# %%
import numpy as np

# %%
arr1= np.random.randint(10,200,10)
arr1
# Out:
# array([179, 182,  78,  87,  55,  96, 139, 135, 102,  78], dtype=int32)

# %%
arr1
# Out:
# array([179, 182,  78,  87,  55,  96, 139, 135, 102,  78], dtype=int32)
