# %% [markdown]
# # Demo

# %% [markdown]
# ## Type

# %% [markdown]
# This is first day for notebook. we are trying to get used it

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=10
c=a+b
c
# Out:
# 20

# %%
def findex (a, b):
    result =1
    for _ in range(b):
        result = result*a
    return result

# %%
findex(3,4)
# Out:
# 81
