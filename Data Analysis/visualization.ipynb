# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr1=np.arange(1,11)
arr2=arr1**2

# %%
plt.plot(arr1,arr2)

# %%
plt.plot(arr1,arr2)
plt.title('Line chart')
plt.xlabel('Number')
plt.ylabel('Square')
#plt.show()
plt.savefig('demo.jpg')

# %%
#plt.plot(arr1,arr2)
plt.figure(figsize=(4,4))
plt.plot(arr1,arr2,marker='p',markerfacecolor='red')

# %%
plt.plot(arr1,arr2,marker='p',markerfacecolor='red',markeredgecolor='red')

# %%
plt.plot(arr1,arr2,marker='p',markerfacecolor='red',markeredgecolor='red',color='black')

# %%
data=pd.read_csv('Datasets/Iris.csv')

# %%
data.shape
# Out:
# (150, 5)

# %%
plt.plot(data['Sepal_Length'],data['Sepal_Width'])

# %%
plt.scatter(data['Sepal_Length'],data['Sepal_Width'])

# %%
data1 =pd.read_csv('Datasets/cars93.csv')

# %%
data1.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
plt.plot(data1['Price'],data1['MPG.city'])

# %%
plt.scatter(data1['Price'],data1['MPG.city'])
plt.xlabel('Price')
plt.ylabel('MPG.city')
# Out:
# Text(0, 0.5, 'MPG.city')

# %%
plt.hist(data1['Price'])
# Out:
# (array([25., 23., 23.,  8.,  6.,  5.,  1.,  1.,  0.,  1.]),
#  array([ 7.4 , 12.85, 18.3 , 23.75, 29.2 , 34.65, 40.1 , 45.55, 51.  ,
#         56.45, 61.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
plt.hist(data1['Price'], edgecolor='black',bins=4)        #bins= no.of columns, edgecolor=colour border
plt.show()

# %%
data1['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
x=data1['Type'].value_counts().index
y=data1['Type'].value_counts().values
plt.figure(figsize=(5,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
data1.groupby('Type')['Price'].mean()
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
data1.groupby('AirBags')['Price'].mean()
# Out:
# AirBags
# Driver & Passenger    26.090909
# Driver only           18.817544
# Name: Price, dtype: float64

# %%
values=data1.groupby('AirBags')['Price'].mean().values
labels=data1.groupby('AirBags')['Price'].mean().index
plt.pie(x=values, labels=labels, autopct= '%0.2f%%') # autooct is used to give range
plt.show()

# %%
plt.boxplot(data1['Rear.seat.room'])
plt.show()

# %%
plt.boxplot(data1['Horsepower'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9024ec7d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f9024eca50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9024ec690>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9024eccd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9024ece10>],
#  'means': []}

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Price', y='Horsepower',data=data1)
# Out:
# <Axes: xlabel='Price', ylabel='Horsepower'>

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.scatterplot(x='Petal_Length', y='Petal_Width',data=data)
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Petal_Width'>

# %%
sns.scatterplot(x='Petal_Length', y='Petal_Width',data=data, hue ='Species')
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Petal_Width'>

# %%
data1.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
sns.countplot(x='AirBags', data=data1)
# Out:
# <Axes: xlabel='AirBags', ylabel='count'>

# %%
sns.countplot(x='AirBags', data=data1, hue='Type')
# Out:
# <Axes: xlabel='AirBags', ylabel='count'>

# %%
# plot max horespower for each type of vehical
sns.barplot(x='Type', y='Horsepower',data=data1)
# Out:
# <Axes: xlabel='Type', ylabel='Horsepower'>

# %%
sns.histplot(x='Price', data=data1)  # in seaborn their is in historical graph the border is automatiicaly come
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(x='Price', data=data1, kde=True)  ## kde is give the distribution curv
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
x=data.drop(['Species'], axis=1)

# %%
x.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
x.corr()  ### it find the corelation between numerical columns
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.109369      0.871754     0.817954
# Sepal_Width      -0.109369     1.000000     -0.420516    -0.356544
# Petal_Length      0.871754    -0.420516      1.000000     0.962757
# Petal_Width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(x.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(x.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data, hue='Species')

# %%
subject=['math', 'science','english']
marks=[85,78, 90]
plt.bar(subject,marks)
plt.xlabel('subject')
plt.ylabel('marks')
plt.title('student performance')
plt.show()

# %%
subject=['math', 'science','english']
marks=[85,78, 90]
plt.pie(marks,labels=subject, autopct='%0.2f%%')
plt.show()

# %%
data=[10,12,114,15,18,19,21,23,30]
plt.boxplot(data)
plt.show()
